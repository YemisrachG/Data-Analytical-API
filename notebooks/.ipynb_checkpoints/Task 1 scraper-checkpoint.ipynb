# %%
# !pip install loguru
import os
import sys

# Create the utils folder and logger.py file
os.makedirs("utils", exist_ok=True)
with open("utils/logger.py", "w") as f:
    f.write("from loguru import logger\n")

# Add current directory to Python path
sys.path.append(os.path.abspath("."))

# Now safely import logger
from utils.logger import logger

logger.info("✅ Logger is working and utils/logger.py is found!")
# Out:
# 2025-07-13 14:40:46.764 | INFO     | __main__:<module>:16 - ✅ Logger is working and utils/logger.py is found!
# Requirement already satisfied: loguru in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (0.7.3)
# Requirement already satisfied: colorama>=0.3.4 in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from loguru) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from loguru) (1.2.0)

# %%
# ✅ Install once per environment
# !pip install --upgrade pip
# !pip install telethon python-dotenv loguru nest_asyncio

# ✅ Imports
import os
import json
import asyncio
from datetime import datetime
from telethon import TelegramClient
from dotenv import load_dotenv
from loguru import logger
import nest_asyncio

nest_asyncio.apply()  # Allows async in Jupyter notebooks

# ✅ Load environment variables
load_dotenv()
api_id_raw = os.getenv("API_ID")
api_hash = os.getenv("API_HASH")
session_name = os.getenv("SESSION_NAME")

if not api_id_raw or not api_hash or not session_name:
    raise ValueError("Please make sure API_ID, API_HASH, and SESSION_NAME are set in the .env file.")

API_ID = int(api_id_raw)
API_HASH = api_hash
SESSION_NAME = session_name

# ✅ Telegram Channels to scrape
CHANNELS = [
    "https://t.me/CheMed123",
    "https://t.me/lobelia4cosmetics",
    "https://t.me/tikvahpharma"
]

# ✅ Prepare storage paths based on today's date
TODAY = datetime.now().strftime("%Y-%m-%d")
BASE_PATH = f"data/raw/telegram_messages/{TODAY}"
IMAGE_PATH = f"data/raw/images/{TODAY}"
os.makedirs(BASE_PATH, exist_ok=True)
os.makedirs(IMAGE_PATH, exist_ok=True)

# ✅ Initialize Telegram client
client = TelegramClient(SESSION_NAME, API_ID, API_HASH)

# ✅ Scrape channel function
async def scrape_channel(channel_url):
    channel_name = channel_url.split("/")[-1]
    logger.info(f"Scraping channel: {channel_name}")
    messages_data = []
    channel_img_path = os.path.join(IMAGE_PATH, channel_name)
    os.makedirs(channel_img_path, exist_ok=True)

    try:
        async for message in client.iter_messages(channel_url, limit=100):
            msg = {
                "id": message.id,
                "date": str(message.date),
                "sender_id": message.sender_id,
                "text": message.text,
                "has_photo": bool(message.photo),
                "channel": channel_name
            }

            # Download image if it exists
            if message.photo:
                image_name = f"{message.id}.jpg"
                image_path = os.path.join(channel_img_path, image_name)
                try:
                    await client.download_media(message.photo, file=image_path)
                    msg["image_path"] = image_path
                    logger.debug(f"Downloaded image: {image_path}")
                except Exception as e:
                    logger.warning(f"Image download failed: {e}")
                    msg["image_path"] = None

            messages_data.append(msg)

        # Save JSON file
        out_file = os.path.join(BASE_PATH, f"{channel_name}.json")
        with open(out_file, "w", encoding="utf-8") as f:
            json.dump(messages_data, f, ensure_ascii=False, indent=2)

        logger.success(f"Saved {len(messages_data)} messages from {channel_name}")

    except Exception as e:
        logger.error(f"Error scraping {channel_url}: {e}")

# ✅ Main async runner
async def main():
    await client.start()
    tasks = [scrape_channel(url.strip()) for url in CHANNELS if url.strip()]
    await asyncio.gather(*tasks)
    await client.disconnect()

# ✅ Run the scraping logic
await main()
# Out:
# Requirement already satisfied: pip in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (25.1.1)
# Requirement already satisfied: telethon in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (1.40.0)
# Requirement already satisfied: python-dotenv in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (1.1.1)
# Requirement already satisfied: loguru in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (0.7.3)
# Requirement already satisfied: nest_asyncio in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (1.6.0)
# Requirement already satisfied: pyaes in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from telethon) (1.6.1)
# Requirement already satisfied: rsa in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from telethon) (4.9.1)
# Requirement already satisfied: colorama>=0.3.4 in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from loguru) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from loguru) (1.2.0)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from rsa->telethon) (0.6.1)
# 2025-07-13 14:41:03.431 | INFO     | __main__:scrape_channel:50 - Scraping channel: CheMed123
# 2025-07-13 14:41:03.438 | INFO     | __main__:scrape_channel:50 - Scraping channel: lobelia4cosmetics
# 2025-07-13 14:41:03.443 | INFO     | __main__:scrape_channel:50 - Scraping channel: tikvahpharma
# 2025-07-13 14:41:05.980 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18535.jpg
# 2025-07-13 14:41:07.572 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\97.jpg
# 2025-07-13 14:41:08.564 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18534.jpg
# 2025-07-13 14:41:11.274 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\96.jpg
# 2025-07-13 14:41:11.400 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172453.jpg
# 2025-07-13 14:41:11.604 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18533.jpg
# 2025-07-13 14:41:12.517 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\95.jpg
# 2025-07-13 14:41:13.134 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172452.jpg
# 2025-07-13 14:41:13.990 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18532.jpg
# 2025-07-13 14:41:15.062 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\94.jpg
# 2025-07-13 14:41:16.754 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18531.jpg
# 2025-07-13 14:41:18.505 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172451.jpg
# 2025-07-13 14:41:19.342 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18530.jpg
# 2025-07-13 14:41:19.372 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\93.jpg
# 2025-07-13 14:41:21.441 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18529.jpg
# 2025-07-13 14:41:23.534 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172448.jpg
# 2025-07-13 14:41:23.733 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18528.jpg
# 2025-07-13 14:41:24.036 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\92.jpg
# 2025-07-13 14:41:25.010 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18527.jpg
# 2025-07-13 14:41:25.503 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172442.jpg
# 2025-07-13 14:41:26.301 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\91.jpg
# 2025-07-13 14:41:27.195 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18526.jpg
# 2025-07-13 14:41:27.949 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18525.jpg
# 2025-07-13 14:41:28.460 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172431.jpg
# 2025-07-13 14:41:30.620 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18524.jpg
# 2025-07-13 14:41:31.132 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172422.jpg
# 2025-07-13 14:41:31.676 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18523.jpg
# 2025-07-13 14:41:32.314 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\90.jpg
# 2025-07-13 14:41:32.801 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172415.jpg
# 2025-07-13 14:41:33.521 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18522.jpg
# 2025-07-13 14:41:37.062 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18521.jpg
# 2025-07-13 14:41:37.364 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\88.jpg
# 2025-07-13 14:41:38.117 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172367.jpg
# 2025-07-13 14:41:40.776 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172360.jpg
# 2025-07-13 14:41:41.019 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\87.jpg
# 2025-07-13 14:41:42.165 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172350.jpg
# 2025-07-13 14:41:42.305 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18520.jpg
# 2025-07-13 14:41:44.992 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172345.jpg
# 2025-07-13 14:41:47.706 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\86.jpg
# 2025-07-13 14:41:48.166 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172332.jpg
# 2025-07-13 14:41:50.309 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18519.jpg
# 2025-07-13 14:41:50.501 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172325.jpg
# 2025-07-13 14:41:51.202 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\85.jpg
# 2025-07-13 14:41:51.599 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18518.jpg
# 2025-07-13 14:41:52.703 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172313.jpg
# 2025-07-13 14:41:52.871 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18517.jpg
# 2025-07-13 14:41:54.811 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\82.jpg
# 2025-07-13 14:41:55.306 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172307.jpg
# 2025-07-13 14:41:55.476 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18516.jpg
# 2025-07-13 14:41:58.926 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18515.jpg
# 2025-07-13 14:41:59.185 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\81.jpg
# 2025-07-13 14:41:59.308 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172274.jpg
# 2025-07-13 14:41:59.577 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18514.jpg
# 2025-07-13 14:42:01.282 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\80.jpg
# 2025-07-13 14:42:01.971 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172273.jpg
# 2025-07-13 14:42:02.093 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18513.jpg
# 2025-07-13 14:42:04.072 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18512.jpg
# 2025-07-13 14:42:04.595 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\79.jpg
# 2025-07-13 14:42:06.192 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18511.jpg
# 2025-07-13 14:42:07.780 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172272.jpg
# 2025-07-13 14:42:08.333 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18510.jpg
# 2025-07-13 14:42:08.797 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\78.jpg
# 2025-07-13 14:42:11.139 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18509.jpg
# 2025-07-13 14:42:12.651 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172263.jpg
# 2025-07-13 14:42:13.865 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18508.jpg
# 2025-07-13 14:42:14.157 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\77.jpg
# 2025-07-13 14:42:15.035 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172252.jpg
# 2025-07-13 14:42:15.235 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18507.jpg
# 2025-07-13 14:42:16.734 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18506.jpg
# 2025-07-13 14:42:17.167 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172230.jpg
# 2025-07-13 14:42:19.298 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18505.jpg
# 2025-07-13 14:42:19.820 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172229.jpg
# 2025-07-13 14:42:19.849 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\76.jpg
# 2025-07-13 14:42:21.116 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18504.jpg
# 2025-07-13 14:42:21.903 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172209.jpg
# 2025-07-13 14:42:23.847 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18503.jpg
# 2025-07-13 14:42:25.864 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\75.jpg
# 2025-07-13 14:42:26.545 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18502.jpg
# 2025-07-13 14:42:26.948 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172186.jpg
# 2025-07-13 14:42:29.442 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\74.jpg
# 2025-07-13 14:42:30.222 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18501.jpg
# 2025-07-13 14:42:31.295 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172185.jpg
# 2025-07-13 14:42:33.025 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18500.jpg
# 2025-07-13 14:42:34.399 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\71.jpg
# 2025-07-13 14:42:36.051 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18499.jpg
# 2025-07-13 14:42:36.505 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172178.jpg
# 2025-07-13 14:42:38.215 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18498.jpg
# 2025-07-13 14:42:38.737 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172177.jpg
# 2025-07-13 14:42:38.920 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\70.jpg
# 2025-07-13 14:42:39.100 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18497.jpg
# 2025-07-13 14:42:39.548 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172173.jpg
# 2025-07-13 14:42:42.212 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18496.jpg
# 2025-07-13 14:42:42.681 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172172.jpg
# 2025-07-13 14:42:42.879 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\67.jpg
# 2025-07-13 14:42:43.926 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172170.jpg
# 2025-07-13 14:42:44.487 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18495.jpg
# 2025-07-13 14:42:46.209 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172166.jpg
# 2025-07-13 14:42:46.994 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18494.jpg
# 2025-07-13 14:42:47.463 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172141.jpg
# 2025-07-13 14:42:47.653 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\64.jpg
# 2025-07-13 14:42:48.302 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18493.jpg
# 2025-07-13 14:42:50.508 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\60.jpg
# 2025-07-13 14:42:50.731 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18492.jpg
# 2025-07-13 14:42:51.056 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172136.jpg
# 2025-07-13 14:42:52.821 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\59.jpg
# 2025-07-13 14:42:55.557 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\58.jpg
# 2025-07-13 14:42:57.544 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18491.jpg
# 2025-07-13 14:42:57.667 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172135.jpg
# 2025-07-13 14:43:01.462 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\57.jpg
# 2025-07-13 14:43:04.636 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172129.jpg
# 2025-07-13 14:43:07.303 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18490.jpg
# 2025-07-13 14:43:10.451 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\56.jpg
# 2025-07-13 14:43:10.616 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18489.jpg
# 2025-07-13 14:43:11.273 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172123.jpg
# 2025-07-13 14:43:14.285 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18488.jpg
# 2025-07-13 14:43:15.872 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172122.jpg
# 2025-07-13 14:43:16.057 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\55.jpg
# 2025-07-13 14:43:16.328 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18487.jpg
# 2025-07-13 14:43:17.641 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172114.jpg
# 2025-07-13 14:43:20.678 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18486.jpg
# 2025-07-13 14:43:21.057 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172113.jpg
# 2025-07-13 14:43:21.068 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\53.jpg
# 2025-07-13 14:43:23.243 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18485.jpg
# 2025-07-13 14:43:24.217 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\52.jpg
# 2025-07-13 14:43:24.483 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172112.jpg
# 2025-07-13 14:43:24.835 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18484.jpg
# 2025-07-13 14:43:27.101 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18483.jpg
# 2025-07-13 14:43:27.645 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172111.jpg
# 2025-07-13 14:43:28.497 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\50.jpg
# 2025-07-13 14:43:28.825 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18482.jpg
# 2025-07-13 14:43:29.421 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172109.jpg
# 2025-07-13 14:43:31.524 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\49.jpg
# 2025-07-13 14:43:32.097 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172107.jpg
# 2025-07-13 14:43:32.129 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18481.jpg
# 2025-07-13 14:43:34.486 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172103.jpg
# 2025-07-13 14:43:37.158 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\48.jpg
# 2025-07-13 14:43:38.557 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18480.jpg
# 2025-07-13 14:43:39.784 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\46.jpg
# 2025-07-13 14:43:40.081 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172100.jpg
# 2025-07-13 14:43:40.311 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18479.jpg
# 2025-07-13 14:43:41.276 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\45.jpg
# 2025-07-13 14:43:43.172 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18478.jpg
# 2025-07-13 14:43:43.983 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\44.jpg
# 2025-07-13 14:43:44.237 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\tikvahpharma\172099.jpg
# 2025-07-13 14:43:44.247 | SUCCESS  | __main__:scrape_channel:85 - Saved 100 messages from tikvahpharma
# 2025-07-13 14:43:45.265 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18477.jpg
# 2025-07-13 14:43:46.298 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\43.jpg
# 2025-07-13 14:43:47.798 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18476.jpg
# 2025-07-13 14:43:49.717 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18475.jpg
# 2025-07-13 14:43:50.097 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\41.jpg
# 2025-07-13 14:43:50.753 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18474.jpg
# 2025-07-13 14:43:51.502 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\40.jpg
# 2025-07-13 14:43:51.768 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18473.jpg
# 2025-07-13 14:43:53.049 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\39.jpg
# 2025-07-13 14:43:53.444 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18472.jpg
# 2025-07-13 14:43:54.933 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\38.jpg
# 2025-07-13 14:43:55.638 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18471.jpg
# 2025-07-13 14:43:56.390 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\34.jpg
# 2025-07-13 14:43:56.880 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18470.jpg
# 2025-07-13 14:43:58.824 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18469.jpg
# 2025-07-13 14:43:58.959 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\33.jpg
# 2025-07-13 14:44:00.302 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18468.jpg
# 2025-07-13 14:44:01.428 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\32.jpg
# 2025-07-13 14:44:02.698 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18467.jpg
# 2025-07-13 14:44:03.852 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\31.jpg
# 2025-07-13 14:44:04.072 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18466.jpg
# 2025-07-13 14:44:05.239 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\30.jpg
# 2025-07-13 14:44:05.494 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18465.jpg
# 2025-07-13 14:44:07.533 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18464.jpg
# 2025-07-13 14:44:07.935 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\29.jpg
# 2025-07-13 14:44:09.108 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18463.jpg
# 2025-07-13 14:44:10.007 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\27.jpg
# 2025-07-13 14:44:10.773 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18462.jpg
# 2025-07-13 14:44:11.867 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18461.jpg
# 2025-07-13 14:44:14.704 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18460.jpg
# 2025-07-13 14:44:15.227 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\26.jpg
# 2025-07-13 14:44:16.161 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18459.jpg
# 2025-07-13 14:44:17.302 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\25.jpg
# 2025-07-13 14:44:18.218 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18458.jpg
# 2025-07-13 14:44:19.188 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\23.jpg
# 2025-07-13 14:44:20.431 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18457.jpg
# 2025-07-13 14:44:21.025 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\22.jpg
# 2025-07-13 14:44:21.975 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18456.jpg
# 2025-07-13 14:44:23.232 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18455.jpg
# 2025-07-13 14:44:24.172 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\21.jpg
# 2025-07-13 14:44:25.565 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18454.jpg
# 2025-07-13 14:44:26.794 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18453.jpg
# 2025-07-13 14:44:27.274 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18452.jpg
# 2025-07-13 14:44:28.104 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\20.jpg
# 2025-07-13 14:44:28.486 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18451.jpg
# 2025-07-13 14:44:30.553 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18450.jpg
# 2025-07-13 14:44:31.664 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\19.jpg
# 2025-07-13 14:44:32.319 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18449.jpg
# 2025-07-13 14:44:33.624 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\18.jpg
# 2025-07-13 14:44:34.433 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18448.jpg
# 2025-07-13 14:44:35.458 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\17.jpg
# 2025-07-13 14:44:35.648 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18446.jpg
# 2025-07-13 14:44:36.708 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18445.jpg
# 2025-07-13 14:44:37.419 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\15.jpg
# 2025-07-13 14:44:38.245 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18444.jpg
# 2025-07-13 14:44:40.072 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18443.jpg
# 2025-07-13 14:44:42.297 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18442.jpg
# 2025-07-13 14:44:42.439 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\14.jpg
# 2025-07-13 14:44:47.074 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18441.jpg
# 2025-07-13 14:44:47.879 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\13.jpg
# 2025-07-13 14:44:48.316 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18440.jpg
# 2025-07-13 14:44:48.759 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18439.jpg
# 2025-07-13 14:44:49.941 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\11.jpg
# 2025-07-13 14:44:50.169 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18438.jpg
# 2025-07-13 14:44:51.754 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18437.jpg
# 2025-07-13 14:44:52.091 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\10.jpg
# 2025-07-13 14:44:52.294 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18436.jpg
# 2025-07-13 14:44:52.902 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\9.jpg
# 2025-07-13 14:44:53.096 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\lobelia4cosmetics\18435.jpg
# 2025-07-13 14:44:53.107 | SUCCESS  | __main__:scrape_channel:85 - Saved 100 messages from lobelia4cosmetics
# 2025-07-13 14:44:53.323 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\4.jpg
# 2025-07-13 14:44:53.885 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\3.jpg
# 2025-07-13 14:44:54.561 | DEBUG    | __main__:scrape_channel:73 - Downloaded image: data/raw/images/2025-07-13\CheMed123\2.jpg
# 2025-07-13 14:44:54.567 | SUCCESS  | __main__:scrape_channel:85 - Saved 76 messages from CheMed123
