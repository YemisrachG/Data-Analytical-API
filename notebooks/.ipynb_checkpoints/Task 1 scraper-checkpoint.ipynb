# %%
# !pip install loguru
import os
import sys

# Create the utils folder and logger.py file
os.makedirs("utils", exist_ok=True)
with open("utils/logger.py", "w") as f:
    f.write("from loguru import logger\n")

# Add current directory to Python path
sys.path.append(os.path.abspath("."))

# Now safely import logger
from utils.logger import logger

logger.info("✅ Logger is working and utils/logger.py is found!")
# Out:
# 2025-07-12 21:48:23.380 | INFO     | __main__:<module>:16 - ✅ Logger is working and utils/logger.py is found!
# Requirement already satisfied: loguru in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (0.7.3)
# Requirement already satisfied: colorama>=0.3.4 in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from loguru) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from loguru) (1.2.0)

# %%
# Install dependencies (run once per session)
# !pip install --upgrade pip
# !pip install python-dotenv
# !pip install telethon python-dotenv loguru
# !pip install nest_asyncio


# --- Imports ---
import os
import json
import asyncio
from datetime import datetime
from telethon import TelegramClient
from dotenv import load_dotenv
from loguru import logger

# --- Load environment variables ---
# !import os; print(os.getcwd())
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Debugging: Print the raw value of the environment variable
raw_api_id = os.getenv("API_ID")
print(f"Raw API_ID from environment: {raw_api_id}")
print(f"Type of raw_api_id: {type(raw_api_id)}")

# Attempt to convert to int only if it's not None
if raw_api_id is not None:
    API_ID = int(raw_api_id)
    print(f"Converted API_ID: {API_ID}")
else:
    print("Error: API_ID environment variable is not set or found in .env file.")
    # You might want to raise an error or exit here if API_ID is critical
    raise ValueError("API_ID environment variable not found.")

API_HASH = os.getenv("API_HASH")
SESSION_NAME = os.getenv("SESSION_NAME")

print(f"API_HASH: {API_HASH}")
print(f"SESSION_NAME: {SESSION_NAME}")

# Your rest of the code that uses API_ID, API_HASH, SESSION_NAME


# --- Telegram channels to scrape ---

API_ID = 22907220  # ✅ Integer is OK
API_HASH = "86a40296f77440985ca1f8d74bc66a24"  # ✅ Must be a string
SESSION_NAME = "telegram_scraper"  # ✅ Must be a string

CHANNELS = [
    "https://t.me/CheMed123",
    "https://t.me/lobelia4cosmetics",
    "https://t.me/tikvahpharma"
]

# --- Prepare output folders ---
TODAY = datetime.now().strftime("%Y-%m-%d")
BASE_PATH = f"data/raw/telegram_messages/{TODAY}"
IMAGE_PATH = f"data/raw/images/{TODAY}"
os.makedirs(BASE_PATH, exist_ok=True)
os.makedirs(IMAGE_PATH, exist_ok=True)

# --- Initialize Telegram client ---
client = TelegramClient(SESSION_NAME, API_ID, API_HASH)

# --- Scrape a single channel ---
async def scrape_channel(channel_url):
    channel_name = channel_url.split("/")[-1]
    logger.info(f"Scraping channel: {channel_name}")
    messages_data = []
    channel_img_path = os.path.join(IMAGE_PATH, channel_name)
    os.makedirs(channel_img_path, exist_ok=True)

    try:
        async for message in client.iter_messages(channel_url, limit=100):
            msg = {
                "id": message.id,
                "date": str(message.date),
                "sender_id": message.sender_id,
                "text": message.text,
                "has_photo": bool(message.photo),
                "channel": channel_name
            }

            # Download image if it exists
            if message.photo:
                image_name = f"{message.id}.jpg"
                image_path = os.path.join(channel_img_path, image_name)
                try:
                    await client.download_media(message.photo, file=image_path)
                    msg["image_path"] = image_path
                    logger.debug(f"Downloaded image: {image_path}")
                except Exception as e:
                    logger.warning(f"Image download failed: {e}")
                    msg["image_path"] = None

            messages_data.append(msg)

        # Save messages as JSON
        out_file = os.path.join(BASE_PATH, f"{channel_name}.json")
        with open(out_file, "w", encoding="utf-8") as f:
            json.dump(messages_data, f, ensure_ascii=False, indent=2)

        logger.success(f"Saved {len(messages_data)} messages from {channel_name}")

    except Exception as e:
        logger.error(f"Error scraping {channel_url}: {e}")

# --- Main function ---
async def main():
    await client.start()
    tasks = [scrape_channel(url.strip()) for url in CHANNELS if url.strip()]
    await asyncio.gather(*tasks)
    await client.disconnect()

# --- Entry point ---
if __name__ == "__main__":

 import nest_asyncio
nest_asyncio.apply()
await main()
# Out:
# Requirement already satisfied: pip in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (25.1.1)
# Requirement already satisfied: python-dotenv in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (1.1.1)
# Requirement already satisfied: telethon in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (1.40.0)
# Requirement already satisfied: python-dotenv in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (1.1.1)
# Requirement already satisfied: loguru in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (0.7.3)
# Requirement already satisfied: pyaes in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from telethon) (1.6.1)
# Requirement already satisfied: rsa in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from telethon) (4.9.1)
# Requirement already satisfied: colorama>=0.3.4 in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from loguru) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from loguru) (1.2.0)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (from rsa->telethon) (0.6.1)
# Requirement already satisfied: nest_asyncio in d:\wk 7 data engineering challenge\data-analytical-api\venv\lib\site-packages (1.6.0)
# Raw API_ID from environment: 22907220
# Type of raw_api_id: <class 'str'>
# Converted API_ID: 22907220
# API_HASH: 86a40296f77440985ca1f8d74bc66a24
# SESSION_NAME: telegram_scraper
# 'import' is not recognized as an internal or external command,
# operable program or batch file.
# Please enter your phone (or bot token):  +251930003856
# Telegram is having internal issues AuthRestartError: Restart the authorization process (caused by SendCodeRequest)
# Please enter the code you received:  21452
# Please enter your password:  ········
# Invalid password. Please try again
# Please enter your password:  ········
# 2025-07-12 22:06:22.430 | INFO     | __main__:scrape_channel:73 - Scraping channel: CheMed123
# 2025-07-12 22:06:22.433 | INFO     | __main__:scrape_channel:73 - Scraping channel: lobelia4cosmetics
# 2025-07-12 22:06:22.436 | INFO     | __main__:scrape_channel:73 - Scraping channel: tikvahpharma
# Signed in successfully as Yemisrach Tigiste; remember to not break the ToS or you will risk an account ban!
# 2025-07-12 22:06:23.924 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\lobelia4cosmetics\18535.jpg
# 2025-07-12 22:06:24.221 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\CheMed123\97.jpg
# 2025-07-12 22:06:25.549 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\lobelia4cosmetics\18534.jpg
# 2025-07-12 22:06:26.172 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\tikvahpharma\172367.jpg
# 2025-07-12 22:06:26.262 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\lobelia4cosmetics\18533.jpg
# 2025-07-12 22:06:26.499 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\CheMed123\96.jpg
# 2025-07-12 22:06:26.743 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\tikvahpharma\172360.jpg
# 2025-07-12 22:06:27.007 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\lobelia4cosmetics\18532.jpg
# 2025-07-12 22:06:27.360 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\CheMed123\95.jpg
# 2025-07-12 22:06:27.663 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\tikvahpharma\172350.jpg
# 2025-07-12 22:06:28.054 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\lobelia4cosmetics\18531.jpg
# 2025-07-12 22:06:28.418 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\tikvahpharma\172345.jpg
# 2025-07-12 22:06:28.811 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\CheMed123\94.jpg
# 2025-07-12 22:06:29.154 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\lobelia4cosmetics\18530.jpg
# 2025-07-12 22:06:29.554 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\tikvahpharma\172332.jpg
# 2025-07-12 22:06:30.109 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\lobelia4cosmetics\18529.jpg
# 2025-07-12 22:06:30.217 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\tikvahpharma\172325.jpg
# 2025-07-12 22:06:30.398 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\CheMed123\93.jpg
# 2025-07-12 22:06:30.518 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\lobelia4cosmetics\18528.jpg
# 2025-07-12 22:06:30.751 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\tikvahpharma\172313.jpg
# 2025-07-12 22:06:31.497 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\CheMed123\92.jpg
# 2025-07-12 22:06:31.771 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\tikvahpharma\172307.jpg
# 2025-07-12 22:06:32.098 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\lobelia4cosmetics\18527.jpg
# 2025-07-12 22:06:32.418 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\CheMed123\91.jpg
# 2025-07-12 22:06:33.563 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\lobelia4cosmetics\18526.jpg
# 2025-07-12 22:06:34.082 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\tikvahpharma\172274.jpg
# 2025-07-12 22:06:34.329 | DEBUG    | __main__:scrape_channel:96 - Downloaded image: data/raw/images/2025-07-12\lobelia4cosmetics\